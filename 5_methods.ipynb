# %%
# !git clone https://github.com/debi2023-group3/Transformer-based-solutions-for-the-long-term-time-series-forecasting.git

# Navigate into the repository directory
# %cd Transformer-based-solutions-for-the-long-term-time-series-forecasting
# Out:
# Cloning into 'Transformer-based-solutions-for-the-long-term-time-series-forecasting'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 332 (delta 8), reused 18 (delta 5), pack-reused 307
# Receiving objects: 100% (332/332), 135.62 MiB | 16.08 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# /content/Transformer-based-solutions-for-the-long-term-time-series-forecasting

# %%
# !pip install -r requirements.txt
# Out:
# Collecting einops==0.6.1 (from -r requirements.txt (line 1))
#   Downloading einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting numpy==1.23.5 (from -r requirements.txt (line 2))
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting pandas==2.0.1 (from -r requirements.txt (line 3))
#   Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scikit_learn==1.2.2 (from -r requirements.txt (line 4))
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.9.1 (from -r requirements.txt (line 5))
#   Downloading scipy-1.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting torchscan==0.1.2 (from -r requirements.txt (line 6))
#   Downloading torchscan-0.1.2-py3-none-any.whl.metadata (26 kB)
# Collecting tqdm==4.65.0 (from -r requirements.txt (line 7))
#   Downloading tqdm-4.65.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.2 MB/s eta 0:00:00
# Collecting opendatasets==0.1.22 (from -r requirements.txt (line 8))
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Collecting torch==1.13.1 (from -r requirements.txt (line 9))
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.1->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.1->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.1->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.2.2->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.2.2->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets==0.1.22->-r requirements.txt (line 8)) (1.6.17)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets==0.1.22->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r requirements.txt (line 9)) (4.12.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.1->-r requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.1->-r requirements.txt (line 9))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements.txt (line 9)) (71.0.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements.txt (line 9)) (0.44.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.1->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (2024.7.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets==0.1.22->-r requirements.txt (line 8)) (3.7)
# Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.0 MB/s eta 0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 94.8 MB/s eta 0:00:00
# Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 103.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 100.9 MB/s eta 0:00:00
# Downloading scipy-1.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 13.6 MB/s eta 0:00:00
# Downloading torchscan-0.1.2-py3-none-any.whl (30 kB)
# Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.4 MB/s eta 0:00:00
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 60.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 42.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: tqdm, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, einops, scipy, pandas, nvidia-cudnn-cu11, torch, scikit_learn, opendatasets, torchscan
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1+cu121
#     Uninstalling torch-2.3.1+cu121:
#       Successfully uninstalled torch-2.3.1+cu121
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgboost 2.1.1 requires nvidia-nccl-cu12; platform_system == "Linux" and platform_machine != "aarch64", which is not installed.
# albucore 0.0.13 requires numpy<2,>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.13 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.13 requires scipy>=1.10.0, but you have scipy 1.9.1 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.0.1 which is incompatible.
# pandas-stubs 2.1.4.231227 requires numpy>=1.26.0; python_version < "3.13", but you have numpy 1.23.5 which is incompatible.
# torchaudio 2.3.1+cu121 requires torch==2.3.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.18.1+cu121 requires torch==2.3.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed einops-0.6.1 numpy-1.23.5 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 opendatasets-0.1.22 pandas-2.0.1 scikit_learn-1.2.2 scipy-1.9.1 torch-1.13.1 torchscan-0.1.2 tqdm-4.65.0

# %%
import torch
import random
import numpy as np
import sys

# Make sure the correct path is added
sys.path.append('/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting')

from exp.exp_DLinear import Exp_Main as Exp_DLinear
from exp.exp_NLinear import Exp_Main as Exp_NLinear
from exp.exp_Informer import Exp_Informer
from exp.exp_FEDformer import Exp_FEDFormer
from exp.exp_PatchTST import Exp_Main as Exp_PatchTST

# %%
if 'Time-Series-Forcasting-Group3' not in sys.path:
    sys.path += ['Time-Series-Forcasting-Group3']

# Setup seed for reproducibility
fix_seed = 2021
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# Hyperparameters setup
args = dotdict()

# Device Hyperparameters
args.use_multi_gpu = False
args.num_workers = 0
args.use_gpu = torch.cuda.is_available()  # Set to True if GPU is available

# Dataset Hyperparameters
args.data = 'custom'
args.root_path = './Datasets/CustomData/'
args.data_path = 'small.csv'
args.features = 'MS'
args.target = 'System'
args.freq = 'h'
args.timeenc = 1
args.embed = 'timeF'
args.padding = 0

# %%
args.attn = 'prob'
args.d_model = 512
args.n_heads = 8
args.factor = 5
args.dropout = 0.1
args.d_ff = 2048
args.activation = 'gelu'
args.mix = True

# %%
args.enc_in = 24  # Adjust based on your dataset's features
args.dec_in = 24
args.c_out = 1
args.e_layers = 2
args.d_layers = 1
args.seq_len = 336
args.label_len = 48
args.pred_len = 96

# %%
args.distil = True
args.output_attention = False
args.use_amp = False
args.train_only = True
args.train_epochs = 6
args.batch_size = 32
args.learning_rate = 0.01
args.lradj = 'type1'
args.loss = 'mse'
args.patience = 3
args.des = 'Exp'
args.itr = 1

# %%
args.modes = 32
args.moving_avg = [5]
args.embed_type = 1

# Initialize the model list and experiment classes
model_list = {
    'DLinear': Exp_DLinear,
    'NLinear': Exp_NLinear,
    'Informer': Exp_Informer,
    'FEDformer': Exp_FEDFormer,
    'PatchTST': Exp_PatchTST
}

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
args.gpu = 0  # Specify the first GPU

# %%
import os
import sys
import torch
from exp.exp_DLinear import Exp_Main

# Ensure the project files are accessible
project_path = '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting'
if project_path not in sys.path:
    sys.path += [project_path]

# Define a dotdict to hold hyperparameters
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# Initialize the arguments with your dataset configuration
args = dotdict()

######################### Device Hyperparameters  ##########################
args.use_multi_gpu = False
args.num_workers = 0
args.use_gpu = torch.cuda.is_available()
args.gpu = 0

######################### Dataset Hyperparameters  ##########################
args.data = 'custom'            # Name your dataset
args.root_path = '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting/Datasets/CustomData/'  # Root path where your dataset is stored
args.data_path = 'my.csv'           # Path to your dataset file
args.features = 'M'                 # Multivariate predict multivariate
args.target = 'System'              # Target feature in your dataset
args.freq = 'h'                     # Frequency: hourly data
args.embed = 'timeF'                # Time features encoding
args.padding = 0                    # Padding (if needed)

######################### Experiment Hyperparameters  ##########################
args.train_only = True
args.train_epochs = 30              # Number of epochs to train
args.batch_size = 32                # Batch size for training
args.learning_rate = 0.05           # Initial learning rate
args.lradj = 'type1'                # Learning rate adjustment strategy
args.loss = 'mse'                   # Loss function
args.patience = 3                   # Early stopping patience
args.des = 'Exp'                    # Experiment description
args.itr  = 1

# Model-specific hyperparameters
args.model = 'DLinear'
args.checkpoints = './Checkpoints/DLinear_checkpoints' # Where to save checkpoints
args.enc_in = 49                  # Number of input features
args.label_len = 48               # Length of the start token series used in the decoder
args.seq_len = 336                # Input sequence length
args.pred_len = 96                # Prediction length

# Set the experiment settings
setting = f'{args.model}_train_on_{args.data}_{args.pred_len}_test'
print(f"Hyperparameter Combination of {setting}:\n")
print(args)

# Initialize the experiment
Exp = Exp_Main
exp = Exp(args)

# Train the model
exp.train(setting)

# Test the model
exp.test(setting)

# Clear GPU cache
torch.cuda.empty_cache()
# Out:
# Hyperparameter Combination of DLinear_train_on_custom_96_test:
#
# {'use_multi_gpu': False, 'num_workers': 0, 'use_gpu': True, 'gpu': 0, 'data': 'custom', 'root_path': '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting/Datasets/CustomData/', 'data_path': 'my.csv', 'features': 'M', 'target': 'System', 'freq': 'h', 'embed': 'timeF', 'padding': 0, 'train_only': True, 'train_epochs': 30, 'batch_size': 32, 'learning_rate': 0.05, 'lradj': 'type1', 'loss': 'mse', 'patience': 3, 'des': 'Exp', 'itr': 1, 'model': 'DLinear', 'checkpoints': './Checkpoints/DLinear_checkpoints', 'enc_in': 49, 'label_len': 48, 'seq_len': 336, 'pred_len': 96}
# Use GPU: cuda:0
# train 68
# ================================================================================
#                                    Training
# ================================================================================
#                                    Epoch 1 Summery
# --------------------------------------------------------------------------------
#      Cost time: 1
#      Steps: 2 	 Train Loss: 33.1519441
#      Validation loss decreased (inf --> 33.151944).  Saving model ...
# ================================================================================
# Updating learning rate to 0.05
#                                    Epoch 2 Summery
# --------------------------------------------------------------------------------
#      Cost time: 2
#      Steps: 2 	 Train Loss: 13.8399391
#      Validation loss decreased (33.151944 --> 13.839939).  Saving model ...
# ================================================================================
# Updating learning rate to 0.025
#                                    Epoch 3 Summery
# --------------------------------------------------------------------------------
#      Cost time: 3
#      Steps: 2 	 Train Loss: 35.3240070
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 0.0125
#                                    Epoch 4 Summery
# --------------------------------------------------------------------------------
#      Cost time: 4
#      Steps: 2 	 Train Loss: 13.9161396
#      EarlyStopping counter: 2 out of 3
# ================================================================================
# Updating learning rate to 0.00625
#                                    Epoch 5 Summery
# --------------------------------------------------------------------------------
#      Cost time: 5
#      Steps: 2 	 Train Loss: 4.7679005
#      Validation loss decreased (13.839939 --> 4.767900).  Saving model ...
# ================================================================================
# Updating learning rate to 0.003125
#                                    Epoch 6 Summery
# --------------------------------------------------------------------------------
#      Cost time: 6
#      Steps: 2 	 Train Loss: 2.3455228
#      Validation loss decreased (4.767900 --> 2.345523).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0015625
#                                    Epoch 7 Summery
# --------------------------------------------------------------------------------
#      Cost time: 7
#      Steps: 2 	 Train Loss: 1.7963657
#      Validation loss decreased (2.345523 --> 1.796366).  Saving model ...
# ================================================================================
# Updating learning rate to 0.00078125
#                                    Epoch 8 Summery
# --------------------------------------------------------------------------------
#      Cost time: 8
#      Steps: 2 	 Train Loss: 1.5562646
#      Validation loss decreased (1.796366 --> 1.556265).  Saving model ...
# ================================================================================
# Updating learning rate to 0.000390625
#                                    Epoch 9 Summery
# --------------------------------------------------------------------------------
#      Cost time: 9
#      Steps: 2 	 Train Loss: 1.4780265
#      Validation loss decreased (1.556265 --> 1.478027).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0001953125
#                                    Epoch 10 Summery
# --------------------------------------------------------------------------------
#      Cost time: 10
#      Steps: 2 	 Train Loss: 1.4443705
#      Validation loss decreased (1.478027 --> 1.444371).  Saving model ...
# ================================================================================
# Updating learning rate to 9.765625e-05
#                                    Epoch 11 Summery
# --------------------------------------------------------------------------------
#      Cost time: 11
#      Steps: 2 	 Train Loss: 1.4118748
#      Validation loss decreased (1.444371 --> 1.411875).  Saving model ...
# ================================================================================
# Updating learning rate to 4.8828125e-05
#                                    Epoch 12 Summery
# --------------------------------------------------------------------------------
#      Cost time: 12
#      Steps: 2 	 Train Loss: 1.4314111
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 2.44140625e-05
#                                    Epoch 13 Summery
# --------------------------------------------------------------------------------
#      Cost time: 13
#      Steps: 2 	 Train Loss: 1.3920583
#      Validation loss decreased (1.411875 --> 1.392058).  Saving model ...
# ================================================================================
# Updating learning rate to 1.220703125e-05
#                                    Epoch 14 Summery
# --------------------------------------------------------------------------------
#      Cost time: 14
#      Steps: 2 	 Train Loss: 1.4168717
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 6.103515625e-06
#                                    Epoch 15 Summery
# --------------------------------------------------------------------------------
#      Cost time: 15
#      Steps: 2 	 Train Loss: 1.3887199
#      Validation loss decreased (1.392058 --> 1.388720).  Saving model ...
# ================================================================================
# Updating learning rate to 3.0517578125e-06
#                                    Epoch 16 Summery
# --------------------------------------------------------------------------------
#      Cost time: 16
#      Steps: 2 	 Train Loss: 1.3877296
#      Validation loss decreased (1.388720 --> 1.387730).  Saving model ...
# ================================================================================
# Updating learning rate to 1.52587890625e-06
#                                    Epoch 17 Summery
# --------------------------------------------------------------------------------
#      Cost time: 17
#      Steps: 2 	 Train Loss: 1.4089937
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 7.62939453125e-07
#                                    Epoch 18 Summery
# --------------------------------------------------------------------------------
#      Cost time: 18
#      Steps: 2 	 Train Loss: 1.4185337
#      EarlyStopping counter: 2 out of 3
# ================================================================================
# Updating learning rate to 3.814697265625e-07
#                                    Epoch 19 Summery
# --------------------------------------------------------------------------------
#      Cost time: 19
#      Steps: 2 	 Train Loss: 1.3981161
#      EarlyStopping counter: 3 out of 3
#                       Early stopping
# test 4
# mae:0.9019697308540344, mse:1.3600786924362183, rmse:1.1662241220474243, mape:4.675704002380371, mspe:1515.2099609375

# %% [markdown]
# # 192

# %%
import os
import sys
import torch
from exp.exp_DLinear import Exp_Main

# Ensure the project files are accessible
project_path = '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting'
if project_path not in sys.path:
    sys.path += [project_path]

# Define a dotdict to hold hyperparameters
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# Initialize the arguments with your dataset configuration
args = dotdict()

######################### Device Hyperparameters  ##########################
args.use_multi_gpu = False
args.num_workers = 0
args.use_gpu = torch.cuda.is_available()
args.gpu = 0

######################### Dataset Hyperparameters  ##########################
args.data = 'custom'            # Name your dataset
args.root_path = '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting/Datasets/CustomData/'  # Root path where your dataset is stored
args.data_path = 'my_.csv'           # Path to your dataset file
args.features = 'M'                 # Multivariate predict multivariate
args.target = 'System'              # Target feature in your dataset
args.freq = 'h'                     # Frequency: hourly data
args.embed = 'timeF'                # Time features encoding
args.padding = 0                    # Padding (if needed)

######################### Experiment Hyperparameters  ##########################
args.train_only = True
args.train_epochs = 30              # Number of epochs to train
args.batch_size = 32                # Batch size for training
args.learning_rate = 0.05           # Initial learning rate
args.lradj = 'type1'                # Learning rate adjustment strategy
args.loss = 'mse'                   # Loss function
args.patience = 3                   # Early stopping patience
args.des = 'Exp'                    # Experiment description
args.itr  = 1

# Model-specific hyperparameters
args.model = 'DLinear'
args.checkpoints = './Checkpoints/DLinear_checkpoints' # Where to save checkpoints
args.enc_in = 49                  # Number of input features
args.label_len = 48               # Length of the start token series used in the decoder
args.seq_len = 336                # Input sequence length
args.pred_len = 96                # Prediction length


setting = f'{args.model}_train_on_{args.data}_{args.pred_len}_test'
print(f"Hyperparameter Combination of {setting}:\n")
print(args)

Exp = Exp_Main
exp = Exp(args)

exp.train(setting)

exp.test(setting)

torch.cuda.empty_cache()
# Out:
# Hyperparameter Combination of DLinear_train_on_custom_96_test:
#
# {'use_multi_gpu': False, 'num_workers': 0, 'use_gpu': True, 'gpu': 0, 'data': 'custom', 'root_path': '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting/Datasets/CustomData/', 'data_path': 'my_.csv', 'features': 'M', 'target': 'System', 'freq': 'h', 'embed': 'timeF', 'padding': 0, 'train_only': True, 'train_epochs': 30, 'batch_size': 32, 'learning_rate': 0.05, 'lradj': 'type1', 'loss': 'mse', 'patience': 3, 'des': 'Exp', 'itr': 1, 'model': 'DLinear', 'checkpoints': './Checkpoints/DLinear_checkpoints', 'enc_in': 49, 'label_len': 48, 'seq_len': 336, 'pred_len': 96}
# Use GPU: cuda:0
# train 112047
# ================================================================================
#                                    Training
# ================================================================================
# Epoch: 1, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.2101181 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 679.7106 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.3235588 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 663.1829 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.2975780 (MSE)
#     Speed: 0.0079 sec/iter
#     Left time: 819.0773 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.3117352 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 643.9454 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.2816634 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 649.2052 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.9761983 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 662.8633 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.5117260 (MSE)
#     Speed: 0.0077 sec/iter
#     Left time: 784.9409 sec
# --------------------------------------------------------------------------------
#                                    Epoch 1 Summery
# --------------------------------------------------------------------------------
#      Cost time: 1
#      Steps: 3501 	 Train Loss: 0.6010451
#      Validation loss decreased (inf --> 0.601045).  Saving model ...
# ================================================================================
# Updating learning rate to 0.05
# Epoch: 2, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 1.1827556 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 632.7863 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.3548935 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 630.3505 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.3286320 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 653.4078 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.4141723 (MSE)
#     Speed: 0.0075 sec/iter
#     Left time: 749.8963 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.4955064 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 613.9106 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.3659102 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 599.7741 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.4901408 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 630.6241 sec
# --------------------------------------------------------------------------------
#                                    Epoch 2 Summery
# --------------------------------------------------------------------------------
#      Cost time: 2
#      Steps: 3501 	 Train Loss: 0.4900693
#      Validation loss decreased (0.601045 --> 0.490069).  Saving model ...
# ================================================================================
# Updating learning rate to 0.025
# Epoch: 3, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.2269327 (MSE)
#     Speed: 0.0076 sec/iter
#     Left time: 743.9210 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.2558810 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 605.1437 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.2130262 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 587.9178 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.2304375 (MSE)
#     Speed: 0.0067 sec/iter
#     Left time: 643.3562 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.2637108 (MSE)
#     Speed: 0.0075 sec/iter
#     Left time: 716.0692 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2355708 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 605.0408 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2417791 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 608.6049 sec
# --------------------------------------------------------------------------------
#                                    Epoch 3 Summery
# --------------------------------------------------------------------------------
#      Cost time: 3
#      Steps: 3501 	 Train Loss: 0.2483463
#      Validation loss decreased (0.490069 --> 0.248346).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0125
# Epoch: 4, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.2023923 (MSE)
#     Speed: 0.0072 sec/iter
#     Left time: 680.9660 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1762936 (MSE)
#     Speed: 0.0071 sec/iter
#     Left time: 659.3825 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1793126 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 594.6567 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1947953 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 603.8336 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.2189457 (MSE)
#     Speed: 0.0082 sec/iter
#     Left time: 751.6086 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2473882 (MSE)
#     Speed: 0.0066 sec/iter
#     Left time: 606.8012 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2300381 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 584.4002 sec
# --------------------------------------------------------------------------------
#                                    Epoch 4 Summery
# --------------------------------------------------------------------------------
#      Cost time: 4
#      Steps: 3501 	 Train Loss: 0.2079670
#      Validation loss decreased (0.248346 --> 0.207967).  Saving model ...
# ================================================================================
# Updating learning rate to 0.00625
# Epoch: 5, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1906231 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 570.5243 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1638438 (MSE)
#     Speed: 0.0079 sec/iter
#     Left time: 709.2337 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.2004451 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 563.2401 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1845379 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 574.8170 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1889744 (MSE)
#     Speed: 0.0066 sec/iter
#     Left time: 581.8707 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2000424 (MSE)
#     Speed: 0.0078 sec/iter
#     Left time: 683.8690 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2111494 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 561.6141 sec
# --------------------------------------------------------------------------------
#                                    Epoch 5 Summery
# --------------------------------------------------------------------------------
#      Cost time: 5
#      Steps: 3501 	 Train Loss: 0.1904557
#      Validation loss decreased (0.207967 --> 0.190456).  Saving model ...
# ================================================================================
# Updating learning rate to 0.003125
# Epoch: 6, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1958186 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 559.5999 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1729292 (MSE)
#     Speed: 0.0069 sec/iter
#     Left time: 599.0278 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1891854 (MSE)
#     Speed: 0.0073 sec/iter
#     Left time: 624.3194 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1709284 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 553.1849 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1724395 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 531.5911 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2039168 (MSE)
#     Speed: 0.0074 sec/iter
#     Left time: 622.5226 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1753210 (MSE)
#     Speed: 0.0069 sec/iter
#     Left time: 583.1398 sec
# --------------------------------------------------------------------------------
#                                    Epoch 6 Summery
# --------------------------------------------------------------------------------
#      Cost time: 6
#      Steps: 3501 	 Train Loss: 0.1826134
#      Validation loss decreased (0.190456 --> 0.182613).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0015625
# Epoch: 7, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1819698 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 546.3482 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1695343 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 534.4175 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1841152 (MSE)
#     Speed: 0.0085 sec/iter
#     Left time: 703.1701 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1705772 (MSE)
#     Speed: 0.0068 sec/iter
#     Left time: 554.9710 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1645207 (MSE)
#     Speed: 0.0067 sec/iter
#     Left time: 543.3070 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1765484 (MSE)
#     Speed: 0.0071 sec/iter
#     Left time: 571.6787 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1705049 (MSE)
#     Speed: 0.0080 sec/iter
#     Left time: 646.7983 sec
# --------------------------------------------------------------------------------
#                                    Epoch 7 Summery
# --------------------------------------------------------------------------------
#      Cost time: 7
#      Steps: 3501 	 Train Loss: 0.1783641
#      Validation loss decreased (0.182613 --> 0.178364).  Saving model ...
# ================================================================================
# Updating learning rate to 0.00078125
# Epoch: 8, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1588517 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 507.9801 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1762187 (MSE)
#     Speed: 0.0066 sec/iter
#     Left time: 520.9600 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1724737 (MSE)
#     Speed: 0.0071 sec/iter
#     Left time: 564.5485 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1804684 (MSE)
#     Speed: 0.0074 sec/iter
#     Left time: 577.4142 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1384413 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 493.2991 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1827311 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 499.4353 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2132386 (MSE)
#     Speed: 0.0076 sec/iter
#     Left time: 583.3504 sec
# --------------------------------------------------------------------------------
#                                    Epoch 8 Summery
# --------------------------------------------------------------------------------
#      Cost time: 8
#      Steps: 3501 	 Train Loss: 0.1759944
#      Validation loss decreased (0.178364 --> 0.175994).  Saving model ...
# ================================================================================
# Updating learning rate to 0.000390625
# Epoch: 9, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1887980 (MSE)
#     Speed: 0.0069 sec/iter
#     Left time: 524.3786 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1737892 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 482.4834 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1614098 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 479.0060 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1734497 (MSE)
#     Speed: 0.0080 sec/iter
#     Left time: 602.8955 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1711074 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 471.4265 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1623356 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 473.6370 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1662778 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 471.9257 sec
# --------------------------------------------------------------------------------
#                                    Epoch 9 Summery
# --------------------------------------------------------------------------------
#      Cost time: 9
#      Steps: 3501 	 Train Loss: 0.1747052
#      Validation loss decreased (0.175994 --> 0.174705).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0001953125
# Epoch: 10, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1508321 (MSE)
#     Speed: 0.0083 sec/iter
#     Left time: 605.9403 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1584975 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 469.1974 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1625369 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 452.0586 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1666580 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 457.0185 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1655817 (MSE)
#     Speed: 0.0077 sec/iter
#     Left time: 545.0748 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1729529 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 437.3111 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1702662 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 434.9866 sec
# --------------------------------------------------------------------------------
#                                    Epoch 10 Summery
# --------------------------------------------------------------------------------
#      Cost time: 10
#      Steps: 3501 	 Train Loss: 0.1739769
#      Validation loss decreased (0.174705 --> 0.173977).  Saving model ...
# ================================================================================
# Updating learning rate to 9.765625e-05
# Epoch: 11, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1601041 (MSE)
#     Speed: 0.0066 sec/iter
#     Left time: 456.8975 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1867385 (MSE)
#     Speed: 0.0076 sec/iter
#     Left time: 522.5736 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1560839 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 430.0529 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1739348 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 421.1447 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1637197 (MSE)
#     Speed: 0.0066 sec/iter
#     Left time: 448.6487 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1896551 (MSE)
#     Speed: 0.0074 sec/iter
#     Left time: 498.6187 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1909560 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 417.3105 sec
# --------------------------------------------------------------------------------
#                                    Epoch 11 Summery
# --------------------------------------------------------------------------------
#      Cost time: 11
#      Steps: 3501 	 Train Loss: 0.1735629
#      Validation loss decreased (0.173977 --> 0.173563).  Saving model ...
# ================================================================================
# Updating learning rate to 4.8828125e-05
# Epoch: 12, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1706690 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 417.6540 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1548897 (MSE)
#     Speed: 0.0069 sec/iter
#     Left time: 453.5257 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1701680 (MSE)
#     Speed: 0.0070 sec/iter
#     Left time: 454.7955 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1610685 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 403.3782 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1911605 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 400.0864 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1759268 (MSE)
#     Speed: 0.0073 sec/iter
#     Left time: 465.2704 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2209292 (MSE)
#     Speed: 0.0069 sec/iter
#     Left time: 436.0083 sec
# --------------------------------------------------------------------------------
#                                    Epoch 12 Summery
# --------------------------------------------------------------------------------
#      Cost time: 12
#      Steps: 3501 	 Train Loss: 0.1733290
#      Validation loss decreased (0.173563 --> 0.173329).  Saving model ...
# ================================================================================
# Updating learning rate to 2.44140625e-05
# Epoch: 13, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1651612 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 398.9780 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1787595 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 383.6808 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1846705 (MSE)
#     Speed: 0.0074 sec/iter
#     Left time: 457.4990 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1620397 (MSE)
#     Speed: 0.0066 sec/iter
#     Left time: 401.8235 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.2038437 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 368.5105 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1962039 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 372.5004 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2211504 (MSE)
#     Speed: 0.0076 sec/iter
#     Left time: 452.1496 sec
# --------------------------------------------------------------------------------
#                                    Epoch 13 Summery
# --------------------------------------------------------------------------------
#      Cost time: 13
#      Steps: 3501 	 Train Loss: 0.1732157
#      Validation loss decreased (0.173329 --> 0.173216).  Saving model ...
# ================================================================================
# Updating learning rate to 1.220703125e-05
# Epoch: 14, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1882787 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 382.6907 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1699658 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 363.5903 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1715422 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 353.9099 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1720267 (MSE)
#     Speed: 0.0078 sec/iter
#     Left time: 445.9679 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1781137 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 357.2686 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1678575 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 352.4154 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1766271 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 343.1373 sec
# --------------------------------------------------------------------------------
#                                    Epoch 14 Summery
# --------------------------------------------------------------------------------
#      Cost time: 14
#      Steps: 3501 	 Train Loss: 0.1731497
#      Validation loss decreased (0.173216 --> 0.173150).  Saving model ...
# ================================================================================
# Updating learning rate to 6.103515625e-06
# Epoch: 15, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1828807 (MSE)
#     Speed: 0.0078 sec/iter
#     Left time: 431.0800 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1592471 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 346.0381 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1624552 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 333.9323 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1529557 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 335.1077 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1805602 (MSE)
#     Speed: 0.0077 sec/iter
#     Left time: 414.5506 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1710479 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 326.9089 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1772786 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 319.7456 sec
# --------------------------------------------------------------------------------
#                                    Epoch 15 Summery
# --------------------------------------------------------------------------------
#      Cost time: 15
#      Steps: 3501 	 Train Loss: 0.1731152
#      Validation loss decreased (0.173150 --> 0.173115).  Saving model ...
# ================================================================================
# Updating learning rate to 3.0517578125e-06
# Epoch: 16, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1831571 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 324.2726 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1722050 (MSE)
#     Speed: 0.0079 sec/iter
#     Left time: 407.9402 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1929333 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 312.4390 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1793223 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 314.4944 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1634163 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 310.9193 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1846500 (MSE)
#     Speed: 0.0079 sec/iter
#     Left time: 389.0706 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1838675 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 303.4172 sec
# --------------------------------------------------------------------------------
#                                    Epoch 16 Summery
# --------------------------------------------------------------------------------
#      Cost time: 16
#      Steps: 3501 	 Train Loss: 0.1730978
#      Validation loss decreased (0.173115 --> 0.173098).  Saving model ...
# ================================================================================
# Updating learning rate to 1.52587890625e-06
# Epoch: 17, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1589025 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 303.6444 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1691683 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 307.1285 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1562948 (MSE)
#     Speed: 0.0078 sec/iter
#     Left time: 371.6598 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1861758 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 293.4608 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1583371 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 291.1656 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1768985 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 292.6557 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1619807 (MSE)
#     Speed: 0.0076 sec/iter
#     Left time: 345.2686 sec
# --------------------------------------------------------------------------------
#                                    Epoch 17 Summery
# --------------------------------------------------------------------------------
#      Cost time: 17
#      Steps: 3501 	 Train Loss: 0.1730915
#      Validation loss decreased (0.173098 --> 0.173091).  Saving model ...
# ================================================================================
# Updating learning rate to 7.62939453125e-07
# Epoch: 18, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1618867 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 281.2575 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1912533 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 279.0203 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1624803 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 278.4876 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1547390 (MSE)
#     Speed: 0.0074 sec/iter
#     Left time: 323.8633 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1539600 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 269.0098 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1689830 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 261.2123 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1842421 (MSE)
#     Speed: 0.0067 sec/iter
#     Left time: 282.0305 sec
# --------------------------------------------------------------------------------
#                                    Epoch 18 Summery
# --------------------------------------------------------------------------------
#      Cost time: 18
#      Steps: 3501 	 Train Loss: 0.1730808
#      Validation loss decreased (0.173091 --> 0.173081).  Saving model ...
# ================================================================================
# Updating learning rate to 3.814697265625e-07
# Epoch: 19, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1580064 (MSE)
#     Speed: 0.0074 sec/iter
#     Left time: 305.2006 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1803496 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 256.1026 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1602603 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 251.2396 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1681419 (MSE)
#     Speed: 0.0067 sec/iter
#     Left time: 269.6864 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1625030 (MSE)
#     Speed: 0.0072 sec/iter
#     Left time: 285.3383 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1700494 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 238.8348 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1628617 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 241.0751 sec
# --------------------------------------------------------------------------------
#                                    Epoch 19 Summery
# --------------------------------------------------------------------------------
#      Cost time: 19
#      Steps: 3501 	 Train Loss: 0.1730847
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 1.9073486328125e-07
# Epoch: 20, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1622366 (MSE)
#     Speed: 0.0072 sec/iter
#     Left time: 271.8074 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1751041 (MSE)
#     Speed: 0.0072 sec/iter
#     Left time: 269.1790 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1513612 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 234.3329 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1843924 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 231.6942 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1482288 (MSE)
#     Speed: 0.0077 sec/iter
#     Left time: 277.2100 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1884599 (MSE)
#     Speed: 0.0070 sec/iter
#     Left time: 247.8754 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1892438 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 223.7395 sec
# --------------------------------------------------------------------------------
#                                    Epoch 20 Summery
# --------------------------------------------------------------------------------
#      Cost time: 20
#      Steps: 3501 	 Train Loss: 0.1730804
#      Validation loss decreased (0.173081 --> 0.173080).  Saving model ...
# ================================================================================
# Updating learning rate to 9.5367431640625e-08
# Epoch: 21, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1576290 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 219.4211 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1866155 (MSE)
#     Speed: 0.0077 sec/iter
#     Left time: 263.2409 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1830368 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 207.7847 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1832861 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 207.8046 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1875868 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 207.1290 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1837399 (MSE)
#     Speed: 0.0079 sec/iter
#     Left time: 253.3809 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1689692 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 195.2136 sec
# --------------------------------------------------------------------------------
#                                    Epoch 21 Summery
# --------------------------------------------------------------------------------
#      Cost time: 21
#      Steps: 3501 	 Train Loss: 0.1730786
#      Validation loss decreased (0.173080 --> 0.173079).  Saving model ...
# ================================================================================
# Updating learning rate to 4.76837158203125e-08
# Epoch: 22, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1670297 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 192.3385 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1857113 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 188.5748 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1974634 (MSE)
#     Speed: 0.0077 sec/iter
#     Left time: 232.3989 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1665825 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 181.5784 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1924160 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 181.3979 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2063971 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 175.5790 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1763716 (MSE)
#     Speed: 0.0078 sec/iter
#     Left time: 218.6396 sec
# --------------------------------------------------------------------------------
#                                    Epoch 22 Summery
# --------------------------------------------------------------------------------
#      Cost time: 22
#      Steps: 3501 	 Train Loss: 0.1730796
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 2.384185791015625e-08
# Epoch: 23, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1520108 (MSE)
#     Speed: 0.0064 sec/iter
#     Left time: 176.0573 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1751551 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 167.3352 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1763560 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 167.2263 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1557311 (MSE)
#     Speed: 0.0075 sec/iter
#     Left time: 195.5520 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1643127 (MSE)
#     Speed: 0.0063 sec/iter
#     Left time: 159.7873 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1837961 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 154.9898 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1590889 (MSE)
#     Speed: 0.0065 sec/iter
#     Left time: 159.3519 sec
# --------------------------------------------------------------------------------
#                                    Epoch 23 Summery
# --------------------------------------------------------------------------------
#      Cost time: 23
#      Steps: 3501 	 Train Loss: 0.1730815
#      EarlyStopping counter: 2 out of 3
# ================================================================================
# Updating learning rate to 1.1920928955078126e-08
# Epoch: 24, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1528620 (MSE)
#     Speed: 0.0075 sec/iter
#     Left time: 180.2772 sec
# --------------------------------------------------------------------------------
# Epoch: 24, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1510969 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 146.8465 sec
# --------------------------------------------------------------------------------
# Epoch: 24, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1857222 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 142.9866 sec
# --------------------------------------------------------------------------------
# Epoch: 24, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1670533 (MSE)
#     Speed: 0.0068 sec/iter
#     Left time: 152.1101 sec
# --------------------------------------------------------------------------------
# Epoch: 24, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1649724 (MSE)
#     Speed: 0.0072 sec/iter
#     Left time: 159.1091 sec
# --------------------------------------------------------------------------------
# Epoch: 24, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1520195 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 133.4073 sec
# --------------------------------------------------------------------------------
# Epoch: 24, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1989428 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 130.4815 sec
# --------------------------------------------------------------------------------
#                                    Epoch 24 Summery
# --------------------------------------------------------------------------------
#      Cost time: 24
#      Steps: 3501 	 Train Loss: 0.1730795
#      EarlyStopping counter: 3 out of 3
#                       Early stopping
# test 22400
# mae:0.31111782789230347, mse:0.21688123047351837, rmse:0.46570509672164917, mape:4.752504825592041, mspe:2279195.0

# %%
args.data = 'custom'            # Name your dataset
args.root_path = '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting/Datasets/CustomData/'  # Root path where your dataset is stored
args.data_path = 'my_.csv'           # Path to your dataset file
args.features = 'M'                 # Multivariate predict multivariate
args.target = 'System'              # Target feature in your dataset
args.freq = 'h'                     # Frequency: hourly data
args.embed = 'timeF'                # Time features encoding
args.padding = 0


args.train_only = True
args.train_epochs = 30              # Number of epochs to train
args.batch_size = 32                # Batch size for training
args.learning_rate = 0.05           # Initial learning rate
args.lradj = 'type1'                # Learning rate adjustment strategy
args.loss = 'mse'                   # Loss function
args.patience = 3                   # Early stopping patience
args.des = 'Exp'                    # Experiment description
args.itr  = 1

# Model-specific hyperparameters
args.model = 'DLinear'
args.checkpoints = './Checkpoints/DLinear_checkpoints' # Where to save checkpoints

# Adjusted Sequence Lengths to Avoid ValueError
args.enc_in = 49                  # Number of input features
args.label_len = 24               # Adjusted length of the start token series used in the decoder
args.seq_len = 168                # Adjusted input sequence length
args.pred_len = 48                # Adjusted prediction length

# Custom model settings as per your requirement
args.timeenc = 1
args.attn = 'prob'
args.d_model = 512
args.n_heads = 8
args.factor = 5
args.dropout = 0.1
args.d_ff = 2048
args.activation = 'gelu'
args.mix = True
args.dec_in = 24
args.c_out = 1
args.e_layers = 2
args.d_layers = 1
args.distil = True
args.output_attention = False
args.use_amp = False
args.modes = 32
args.moving_avg = [5]
args.embed_type = 1

# Set the experiment settings
used_data = 'custom'  # Custom dataset identifier
setting = f'{args.model}_train_on_{used_data}_{args.pred_len}'
print(f"Hyperparameter Combination of {setting}:\n")
print(args)

# Step 2: Initialize the experiment
crypto_exp = Exp_Main(args)

# Step 3: Train the model
try:
    crypto_exp.train(setting)
except ValueError as e:
    print(f"Error during training: {e}")

# Step 4: Test the model (only if training is successful)
try:
    crypto_exp.test(setting)
except Exception as e:
    print(f"Error during testing: {e}")

# Step 5: Clear GPU cache
torch.cuda.empty_cache()
# Out:
# Hyperparameter Combination of DLinear_train_on_custom_48:
#
# {'use_multi_gpu': False, 'num_workers': 0, 'use_gpu': True, 'gpu': 0, 'data': 'custom', 'root_path': '/content/Transformer-based-solutions-for-the-long-term-time-series-forecasting/Datasets/CustomData/', 'data_path': 'my_.csv', 'features': 'M', 'target': 'System', 'freq': 'h', 'embed': 'timeF', 'padding': 0, 'train_only': True, 'train_epochs': 30, 'batch_size': 32, 'learning_rate': 0.05, 'lradj': 'type1', 'loss': 'mse', 'patience': 3, 'des': 'Exp', 'itr': 1, 'model': 'DLinear', 'checkpoints': './Checkpoints/DLinear_checkpoints', 'enc_in': 49, 'label_len': 24, 'seq_len': 168, 'pred_len': 48, 'timeenc': 1, 'attn': 'prob', 'd_model': 512, 'n_heads': 8, 'factor': 5, 'dropout': 0.1, 'd_ff': 2048, 'activation': 'gelu', 'mix': True, 'dec_in': 24, 'c_out': 1, 'e_layers': 2, 'd_layers': 1, 'distil': True, 'output_attention': False, 'use_amp': False, 'modes': 32, 'moving_avg': [5], 'embed_type': 1}
# Use GPU: cuda:0
# train 112263
# ================================================================================
#                                    Training
# ================================================================================
# Epoch: 1, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1820496 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 461.6329 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.2106619 (MSE)
#     Speed: 0.0055 sec/iter
#     Left time: 570.8690 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.2181191 (MSE)
#     Speed: 0.0051 sec/iter
#     Left time: 531.5605 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.2235557 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 451.2104 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.3349972 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 456.8946 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2440639 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 452.5061 sec
# --------------------------------------------------------------------------------
# Epoch: 1, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2039336 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 465.0897 sec
# --------------------------------------------------------------------------------
#                                    Epoch 1 Summery
# --------------------------------------------------------------------------------
#      Cost time: 1
#      Steps: 3508 	 Train Loss: 0.2770004
#      Validation loss decreased (inf --> 0.277000).  Saving model ...
# ================================================================================
# Updating learning rate to 0.05
# Epoch: 2, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.2083840 (MSE)
#     Speed: 0.0061 sec/iter
#     Left time: 615.8999 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.2271790 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 445.7492 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.2879912 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 442.5242 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.2201540 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 438.0751 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.2814293 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 440.0171 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.2657506 (MSE)
#     Speed: 0.0054 sec/iter
#     Left time: 536.2804 sec
# --------------------------------------------------------------------------------
# Epoch: 2, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2701526 (MSE)
#     Speed: 0.0052 sec/iter
#     Left time: 509.5218 sec
# --------------------------------------------------------------------------------
#                                    Epoch 2 Summery
# --------------------------------------------------------------------------------
#      Cost time: 2
#      Steps: 3508 	 Train Loss: 0.2543334
#      Validation loss decreased (0.277000 --> 0.254333).  Saving model ...
# ================================================================================
# Updating learning rate to 0.025
# Epoch: 3, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1639681 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 444.8758 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1699714 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 431.2985 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1916820 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 427.4015 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1696375 (MSE)
#     Speed: 0.0047 sec/iter
#     Left time: 456.8514 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.2197274 (MSE)
#     Speed: 0.0058 sec/iter
#     Left time: 554.0571 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1635116 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 421.9354 sec
# --------------------------------------------------------------------------------
# Epoch: 3, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.2473106 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 420.7312 sec
# --------------------------------------------------------------------------------
#                                    Epoch 3 Summery
# --------------------------------------------------------------------------------
#      Cost time: 3
#      Steps: 3508 	 Train Loss: 0.1812617
#      Validation loss decreased (0.254333 --> 0.181262).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0125
# Epoch: 4, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1437161 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 435.8862 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1524365 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 424.7624 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1805358 (MSE)
#     Speed: 0.0055 sec/iter
#     Left time: 515.5684 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1507624 (MSE)
#     Speed: 0.0048 sec/iter
#     Left time: 444.2232 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1652966 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 400.8663 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1605181 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 404.8767 sec
# --------------------------------------------------------------------------------
# Epoch: 4, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1585889 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 404.4368 sec
# --------------------------------------------------------------------------------
#                                    Epoch 4 Summery
# --------------------------------------------------------------------------------
#      Cost time: 4
#      Steps: 3508 	 Train Loss: 0.1658455
#      Validation loss decreased (0.181262 --> 0.165846).  Saving model ...
# ================================================================================
# Updating learning rate to 0.00625
# Epoch: 5, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1658843 (MSE)
#     Speed: 0.0049 sec/iter
#     Left time: 447.2770 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1532710 (MSE)
#     Speed: 0.0056 sec/iter
#     Left time: 502.3518 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1517857 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 398.8028 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1610187 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 390.3758 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1599142 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 392.0042 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1645830 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 375.8913 sec
# --------------------------------------------------------------------------------
# Epoch: 5, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1663559 (MSE)
#     Speed: 0.0056 sec/iter
#     Left time: 488.4849 sec
# --------------------------------------------------------------------------------
#                                    Epoch 5 Summery
# --------------------------------------------------------------------------------
#      Cost time: 5
#      Steps: 3508 	 Train Loss: 0.1580551
#      Validation loss decreased (0.165846 --> 0.158055).  Saving model ...
# ================================================================================
# Updating learning rate to 0.003125
# Epoch: 6, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1605084 (MSE)
#     Speed: 0.0050 sec/iter
#     Left time: 434.3557 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1771809 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 378.1179 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1624276 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 379.5582 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1527824 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 373.4923 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1407827 (MSE)
#     Speed: 0.0048 sec/iter
#     Left time: 409.7539 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1709514 (MSE)
#     Speed: 0.0056 sec/iter
#     Left time: 477.6498 sec
# --------------------------------------------------------------------------------
# Epoch: 6, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1387699 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 371.9423 sec
# --------------------------------------------------------------------------------
#                                    Epoch 6 Summery
# --------------------------------------------------------------------------------
#      Cost time: 6
#      Steps: 3508 	 Train Loss: 0.1542809
#      Validation loss decreased (0.158055 --> 0.154281).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0015625
# Epoch: 7, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1376977 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 388.8928 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1472364 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 361.3692 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1504237 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 358.4673 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1484032 (MSE)
#     Speed: 0.0054 sec/iter
#     Left time: 446.6577 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1765807 (MSE)
#     Speed: 0.0050 sec/iter
#     Left time: 411.0872 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1251110 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 356.2329 sec
# --------------------------------------------------------------------------------
# Epoch: 7, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1582589 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 345.9660 sec
# --------------------------------------------------------------------------------
#                                    Epoch 7 Summery
# --------------------------------------------------------------------------------
#      Cost time: 7
#      Steps: 3508 	 Train Loss: 0.1521417
#      Validation loss decreased (0.154281 --> 0.152142).  Saving model ...
# ================================================================================
# Updating learning rate to 0.00078125
# Epoch: 8, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1759024 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 351.8414 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1424781 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 350.2099 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1491089 (MSE)
#     Speed: 0.0060 sec/iter
#     Left time: 476.0457 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1398785 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 341.3959 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1514377 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 339.0780 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1473968 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 331.4667 sec
# --------------------------------------------------------------------------------
# Epoch: 8, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1382909 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 333.6129 sec
# --------------------------------------------------------------------------------
#                                    Epoch 8 Summery
# --------------------------------------------------------------------------------
#      Cost time: 8
#      Steps: 3508 	 Train Loss: 0.1509796
#      Validation loss decreased (0.152142 --> 0.150980).  Saving model ...
# ================================================================================
# Updating learning rate to 0.000390625
# Epoch: 9, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1566983 (MSE)
#     Speed: 0.0052 sec/iter
#     Left time: 400.0286 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1485975 (MSE)
#     Speed: 0.0053 sec/iter
#     Left time: 403.9040 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1482118 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 323.1877 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1657621 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 322.3060 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1533112 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 329.1567 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1560642 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 320.6794 sec
# --------------------------------------------------------------------------------
# Epoch: 9, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1541166 (MSE)
#     Speed: 0.0057 sec/iter
#     Left time: 416.4809 sec
# --------------------------------------------------------------------------------
#                                    Epoch 9 Summery
# --------------------------------------------------------------------------------
#      Cost time: 9
#      Steps: 3508 	 Train Loss: 0.1503479
#      Validation loss decreased (0.150980 --> 0.150348).  Saving model ...
# ================================================================================
# Updating learning rate to 0.0001953125
# Epoch: 10, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1693580 (MSE)
#     Speed: 0.0049 sec/iter
#     Left time: 354.8910 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1638555 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 319.3452 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1722760 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 310.1917 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1449283 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 310.5316 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1544961 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 328.8282 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1415498 (MSE)
#     Speed: 0.0056 sec/iter
#     Left time: 395.7741 sec
# --------------------------------------------------------------------------------
# Epoch: 10, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1579142 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 310.7130 sec
# --------------------------------------------------------------------------------
#                                    Epoch 10 Summery
# --------------------------------------------------------------------------------
#      Cost time: 10
#      Steps: 3508 	 Train Loss: 0.1499711
#      Validation loss decreased (0.150348 --> 0.149971).  Saving model ...
# ================================================================================
# Updating learning rate to 9.765625e-05
# Epoch: 11, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1376639 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 309.8257 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1299646 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 302.6022 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1653468 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 293.9860 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1495009 (MSE)
#     Speed: 0.0055 sec/iter
#     Left time: 377.3840 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1599292 (MSE)
#     Speed: 0.0048 sec/iter
#     Left time: 322.6921 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1351900 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 301.2904 sec
# --------------------------------------------------------------------------------
# Epoch: 11, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1519525 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 288.9002 sec
# --------------------------------------------------------------------------------
#                                    Epoch 11 Summery
# --------------------------------------------------------------------------------
#      Cost time: 11
#      Steps: 3508 	 Train Loss: 0.1497575
#      Validation loss decreased (0.149971 --> 0.149758).  Saving model ...
# ================================================================================
# Updating learning rate to 4.8828125e-05
# Epoch: 12, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1490218 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 289.2577 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1456781 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 302.3987 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1306021 (MSE)
#     Speed: 0.0055 sec/iter
#     Left time: 359.3611 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1398629 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 280.3183 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1429654 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 281.0058 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1437220 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 278.4812 sec
# --------------------------------------------------------------------------------
# Epoch: 12, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1517235 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 277.3466 sec
# --------------------------------------------------------------------------------
#                                    Epoch 12 Summery
# --------------------------------------------------------------------------------
#      Cost time: 12
#      Steps: 3508 	 Train Loss: 0.1496495
#      Validation loss decreased (0.149758 --> 0.149649).  Saving model ...
# ================================================================================
# Updating learning rate to 2.44140625e-05
# Epoch: 13, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1665464 (MSE)
#     Speed: 0.0055 sec/iter
#     Left time: 345.6454 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1620154 (MSE)
#     Speed: 0.0049 sec/iter
#     Left time: 303.5475 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1564284 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 267.1918 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1452123 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 264.6093 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1477247 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 260.8134 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1423578 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 266.8586 sec
# --------------------------------------------------------------------------------
# Epoch: 13, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1385611 (MSE)
#     Speed: 0.0057 sec/iter
#     Left time: 342.0572 sec
# --------------------------------------------------------------------------------
#                                    Epoch 13 Summery
# --------------------------------------------------------------------------------
#      Cost time: 13
#      Steps: 3508 	 Train Loss: 0.1495878
#      Validation loss decreased (0.149649 --> 0.149588).  Saving model ...
# ================================================================================
# Updating learning rate to 1.220703125e-05
# Epoch: 14, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1686143 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 265.8777 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1506659 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 249.4345 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1620938 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 252.9578 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1483069 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 246.0338 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1727996 (MSE)
#     Speed: 0.0051 sec/iter
#     Left time: 292.4770 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1316929 (MSE)
#     Speed: 0.0051 sec/iter
#     Left time: 290.7618 sec
# --------------------------------------------------------------------------------
# Epoch: 14, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1387800 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 243.8320 sec
# --------------------------------------------------------------------------------
#                                    Epoch 14 Summery
# --------------------------------------------------------------------------------
#      Cost time: 14
#      Steps: 3508 	 Train Loss: 0.1495592
#      Validation loss decreased (0.149588 --> 0.149559).  Saving model ...
# ================================================================================
# Updating learning rate to 6.103515625e-06
# Epoch: 15, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1420885 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 250.7434 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1381958 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 238.7774 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1545237 (MSE)
#     Speed: 0.0042 sec/iter
#     Left time: 232.0703 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1574015 (MSE)
#     Speed: 0.0059 sec/iter
#     Left time: 317.3543 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1741728 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 241.3631 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1671413 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 232.3138 sec
# --------------------------------------------------------------------------------
# Epoch: 15, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1402638 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 231.9819 sec
# --------------------------------------------------------------------------------
#                                    Epoch 15 Summery
# --------------------------------------------------------------------------------
#      Cost time: 15
#      Steps: 3508 	 Train Loss: 0.1495420
#      Validation loss decreased (0.149559 --> 0.149542).  Saving model ...
# ================================================================================
# Updating learning rate to 3.0517578125e-06
# Epoch: 16, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1590970 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 231.4695 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1498870 (MSE)
#     Speed: 0.0049 sec/iter
#     Left time: 255.4419 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1587573 (MSE)
#     Speed: 0.0053 sec/iter
#     Left time: 269.8931 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1467150 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 222.4120 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1448549 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 219.1072 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1433117 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 212.6785 sec
# --------------------------------------------------------------------------------
# Epoch: 16, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1568415 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 213.4109 sec
# --------------------------------------------------------------------------------
#                                    Epoch 16 Summery
# --------------------------------------------------------------------------------
#      Cost time: 16
#      Steps: 3508 	 Train Loss: 0.1495310
#      Validation loss decreased (0.149542 --> 0.149531).  Saving model ...
# ================================================================================
# Updating learning rate to 1.52587890625e-06
# Epoch: 17, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1807061 (MSE)
#     Speed: 0.0059 sec/iter
#     Left time: 288.7889 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1485501 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 216.3015 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1560491 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 207.3210 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1421907 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 202.4707 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1611696 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 202.2593 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1529660 (MSE)
#     Speed: 0.0049 sec/iter
#     Left time: 223.7770 sec
# --------------------------------------------------------------------------------
# Epoch: 17, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1550025 (MSE)
#     Speed: 0.0055 sec/iter
#     Left time: 250.7777 sec
# --------------------------------------------------------------------------------
#                                    Epoch 17 Summery
# --------------------------------------------------------------------------------
#      Cost time: 17
#      Steps: 3508 	 Train Loss: 0.1495312
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 7.62939453125e-07
# Epoch: 18, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1376230 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 201.0014 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1396162 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 192.6726 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1495183 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 190.6359 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1621567 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 188.3461 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1379331 (MSE)
#     Speed: 0.0053 sec/iter
#     Left time: 230.3580 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1470052 (MSE)
#     Speed: 0.0050 sec/iter
#     Left time: 214.9657 sec
# --------------------------------------------------------------------------------
# Epoch: 18, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1493862 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 185.8072 sec
# --------------------------------------------------------------------------------
#                                    Epoch 18 Summery
# --------------------------------------------------------------------------------
#      Cost time: 18
#      Steps: 3508 	 Train Loss: 0.1495280
#      Validation loss decreased (0.149531 --> 0.149528).  Saving model ...
# ================================================================================
# Updating learning rate to 3.814697265625e-07
# Epoch: 19, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1603904 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 184.2820 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1396458 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 180.9057 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1346589 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 185.6970 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1573048 (MSE)
#     Speed: 0.0059 sec/iter
#     Left time: 238.4884 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1536185 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 170.8823 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1392193 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 170.2337 sec
# --------------------------------------------------------------------------------
# Epoch: 19, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1510259 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 165.4389 sec
# --------------------------------------------------------------------------------
#                                    Epoch 19 Summery
# --------------------------------------------------------------------------------
#      Cost time: 19
#      Steps: 3508 	 Train Loss: 0.1495272
#      Validation loss decreased (0.149528 --> 0.149527).  Saving model ...
# ================================================================================
# Updating learning rate to 1.9073486328125e-07
# Epoch: 20, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1387300 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 169.4798 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1416222 (MSE)
#     Speed: 0.0053 sec/iter
#     Left time: 199.1082 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1315340 (MSE)
#     Speed: 0.0051 sec/iter
#     Left time: 188.6718 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1567578 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 156.8196 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1398284 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 156.7383 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1447445 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 154.5248 sec
# --------------------------------------------------------------------------------
# Epoch: 20, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1283879 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 156.4670 sec
# --------------------------------------------------------------------------------
#                                    Epoch 20 Summery
# --------------------------------------------------------------------------------
#      Cost time: 20
#      Steps: 3508 	 Train Loss: 0.1495221
#      Validation loss decreased (0.149527 --> 0.149522).  Saving model ...
# ================================================================================
# Updating learning rate to 9.5367431640625e-08
# Epoch: 21, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1475157 (MSE)
#     Speed: 0.0062 sec/iter
#     Left time: 213.2009 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1544222 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 147.0336 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1430602 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 147.2087 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1412744 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 141.9500 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1712606 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 140.5710 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1424136 (MSE)
#     Speed: 0.0049 sec/iter
#     Left time: 156.9577 sec
# --------------------------------------------------------------------------------
# Epoch: 21, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1457510 (MSE)
#     Speed: 0.0054 sec/iter
#     Left time: 171.6608 sec
# --------------------------------------------------------------------------------
#                                    Epoch 21 Summery
# --------------------------------------------------------------------------------
#      Cost time: 21
#      Steps: 3508 	 Train Loss: 0.1495233
#      EarlyStopping counter: 1 out of 3
# ================================================================================
# Updating learning rate to 4.76837158203125e-08
# Epoch: 22, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1371209 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 141.1458 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1584149 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 133.6086 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1521584 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 129.7697 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1454397 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 128.3696 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1483116 (MSE)
#     Speed: 0.0056 sec/iter
#     Left time: 162.7276 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1446927 (MSE)
#     Speed: 0.0048 sec/iter
#     Left time: 136.7199 sec
# --------------------------------------------------------------------------------
# Epoch: 22, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1362525 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 122.0301 sec
# --------------------------------------------------------------------------------
#                                    Epoch 22 Summery
# --------------------------------------------------------------------------------
#      Cost time: 22
#      Steps: 3508 	 Train Loss: 0.1495253
#      EarlyStopping counter: 2 out of 3
# ================================================================================
# Updating learning rate to 2.384185791015625e-08
# Epoch: 23, Iters: 500
# --------------------------------------------------------------------------------
#     Loss : 0.1455569 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 120.9463 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 1000
# --------------------------------------------------------------------------------
#     Loss : 0.1659798 (MSE)
#     Speed: 0.0044 sec/iter
#     Left time: 119.1920 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 1500
# --------------------------------------------------------------------------------
#     Loss : 0.1646575 (MSE)
#     Speed: 0.0046 sec/iter
#     Left time: 121.9935 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 2000
# --------------------------------------------------------------------------------
#     Loss : 0.1691882 (MSE)
#     Speed: 0.0056 sec/iter
#     Left time: 145.8715 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 2500
# --------------------------------------------------------------------------------
#     Loss : 0.1502260 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 110.4609 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 3000
# --------------------------------------------------------------------------------
#     Loss : 0.1832457 (MSE)
#     Speed: 0.0043 sec/iter
#     Left time: 107.9583 sec
# --------------------------------------------------------------------------------
# Epoch: 23, Iters: 3500
# --------------------------------------------------------------------------------
#     Loss : 0.1537344 (MSE)
#     Speed: 0.0045 sec/iter
#     Left time: 110.6258 sec
# --------------------------------------------------------------------------------
#                                    Epoch 23 Summery
# --------------------------------------------------------------------------------
#      Cost time: 23
#      Steps: 3508 	 Train Loss: 0.1495252
#      EarlyStopping counter: 3 out of 3
#                       Early stopping
# test 22448
# mae:0.2863675653934479, mse:0.1894739866256714, rmse:0.43528610467910767, mape:4.871460914611816, mspe:2847288.75
